# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <div style = "color: #923333; font-size: 30px">
#     Reading Dataset
# </div>

# %%
data = pd.read_csv("dis_symp.csv", engine='python') 
data
# Out:
#                               ï»¿Disease  Count of Disease Occurrence  \
# 0     UMLS:C0020538_hypertensive disease                       3363.0
# 1                                    NaN                          NaN
# 2                                    NaN                          NaN
# 3                                    NaN                          NaN
# 4                                    NaN                          NaN
# ...                                  ...                          ...
# 1960       UMLS:C0011127_decubitus ulcer                         42.0
# 1961                                 NaN                          NaN
# 1962                                 NaN                          NaN
# 1963       UMLS:C0011127_decubitus ulcer                         20.0
# 1964                                 NaN                          NaN
#
#                                 Symptom
# 0              UMLS:C0008031_pain chest
# 1     UMLS:C0392680_shortness of breath
# 2               UMLS:C0012833_dizziness
# 3                UMLS:C0004093_asthenia
# 4                    UMLS:C0085639_fall
# ...                                 ...
# 1960      UMLS:C0232257_systolic murmur
# 1961                UMLS:C0871754_frail
# 1962                UMLS:C0015967_fever
# 1963      UMLS:C0232257_systolic murmur
# 1964                UMLS:C0015967_fever
#
# [1965 rows x 3 columns]

# %%
data = data.rename(columns={'ï»¿Disease': 'Disease'})

# %%
data.describe()
# Out:
#        Count of Disease Occurrence
# count                   143.000000
# mean                    265.664336
# std                     399.594829
# min                      14.000000
# 25%                      86.500000
# 50%                     140.000000
# 75%                     274.500000
# max                    3363.000000

# %% [markdown]
# <div style = "color: #923333; font-size: 30px">
#     Cleaning dataset and fill the nan value
# </div>

# %%
data_set = data.copy();
data_set["Disease"] = data_set["Disease"].fillna(method='ffill')
data_set["Count of Disease Occurrence"] = data_set["Count of Disease Occurrence"].fillna(method='ffill')

# %%
data_set.dropna()
# Out:
#                                  Disease  Count of Disease Occurrence  \
# 0     UMLS:C0020538_hypertensive disease                       3363.0
# 1     UMLS:C0020538_hypertensive disease                       3363.0
# 2     UMLS:C0020538_hypertensive disease                       3363.0
# 3     UMLS:C0020538_hypertensive disease                       3363.0
# 4     UMLS:C0020538_hypertensive disease                       3363.0
# ...                                  ...                          ...
# 1960       UMLS:C0011127_decubitus ulcer                         42.0
# 1961       UMLS:C0011127_decubitus ulcer                         42.0
# 1962       UMLS:C0011127_decubitus ulcer                         42.0
# 1963       UMLS:C0011127_decubitus ulcer                         20.0
# 1964       UMLS:C0011127_decubitus ulcer                         20.0
#
#                                 Symptom
# 0              UMLS:C0008031_pain chest
# 1     UMLS:C0392680_shortness of breath
# 2               UMLS:C0012833_dizziness
# 3                UMLS:C0004093_asthenia
# 4                    UMLS:C0085639_fall
# ...                                 ...
# 1960      UMLS:C0232257_systolic murmur
# 1961                UMLS:C0871754_frail
# 1962                UMLS:C0015967_fever
# 1963      UMLS:C0232257_systolic murmur
# 1964                UMLS:C0015967_fever
#
# [1964 rows x 3 columns]

# %%
data_set[data_set["Disease"] == "UMLS:C0020538_hypertensive disease"]
# Out:
#                                Disease  Count of Disease Occurrence  \
# 0   UMLS:C0020538_hypertensive disease                       3363.0
# 1   UMLS:C0020538_hypertensive disease                       3363.0
# 2   UMLS:C0020538_hypertensive disease                       3363.0
# 3   UMLS:C0020538_hypertensive disease                       3363.0
# 4   UMLS:C0020538_hypertensive disease                       3363.0
# 5   UMLS:C0020538_hypertensive disease                       3363.0
# 6   UMLS:C0020538_hypertensive disease                       3363.0
# 7   UMLS:C0020538_hypertensive disease                       3363.0
# 8   UMLS:C0020538_hypertensive disease                       3363.0
# 9   UMLS:C0020538_hypertensive disease                       3363.0
# 10  UMLS:C0020538_hypertensive disease                       3363.0
# 11  UMLS:C0020538_hypertensive disease                       3363.0
# 12  UMLS:C0020538_hypertensive disease                       2150.0
# 13  UMLS:C0020538_hypertensive disease                       2150.0
# 14  UMLS:C0020538_hypertensive disease                       2150.0
# 15  UMLS:C0020538_hypertensive disease                       2150.0
# 16  UMLS:C0020538_hypertensive disease                       2150.0
# 17  UMLS:C0020538_hypertensive disease                       2150.0
# 18  UMLS:C0020538_hypertensive disease                       2150.0
# 19  UMLS:C0020538_hypertensive disease                       2150.0
# 20  UMLS:C0020538_hypertensive disease                       2150.0
# 21  UMLS:C0020538_hypertensive disease                       2150.0
# 22  UMLS:C0020538_hypertensive disease                       2150.0
#
#                                               Symptom
# 0                            UMLS:C0008031_pain chest
# 1                   UMLS:C0392680_shortness of breath
# 2                             UMLS:C0012833_dizziness
# 3                              UMLS:C0004093_asthenia
# 4                                  UMLS:C0085639_fall
# 5                               UMLS:C0039070_syncope
# 6                               UMLS:C0042571_vertigo
# 7   UMLS:C0038990_sweat^UMLS:C0700590_sweating inc...
# 8                           UMLS:C0030252_palpitation
# 9                                UMLS:C0027497_nausea
# 10                      UMLS:C0002962_angina pectoris
# 11                       UMLS:C0438716_pressure chest
# 12                           UMLS:C0008031_pain chest
# 13                  UMLS:C0392680_shortness of breath
# 14                            UMLS:C0012833_dizziness
# 15                             UMLS:C0004093_asthenia
# 16                              UMLS:C0039070_syncope
# 17                                UMLS:C0015967_fever
# 18                              UMLS:C0042571_vertigo
# 19  UMLS:C0038990_sweat^UMLS:C0700590_sweating inc...
# 20                               UMLS:C0027497_nausea
# 21                      UMLS:C0002962_angina pectoris
# 22                       UMLS:C0438716_pressure chest

# %% [markdown]
# <div style = "color: #923333; font-size: 20px">
#     Groupby data and sum the similar data
# </div>

# %%
data_set = data_set.groupby(by=["Disease", "Symptom"], as_index=False).aggregate(pd.np.sum)

# %%
data_set[data_set["Disease"] == "UMLS:C0020538_hypertensive disease"]
# Out:
#                                 Disease  \
# 859  UMLS:C0020538_hypertensive disease
# 860  UMLS:C0020538_hypertensive disease
# 861  UMLS:C0020538_hypertensive disease
# 862  UMLS:C0020538_hypertensive disease
# 863  UMLS:C0020538_hypertensive disease
# 864  UMLS:C0020538_hypertensive disease
# 865  UMLS:C0020538_hypertensive disease
# 866  UMLS:C0020538_hypertensive disease
# 867  UMLS:C0020538_hypertensive disease
# 868  UMLS:C0020538_hypertensive disease
# 869  UMLS:C0020538_hypertensive disease
# 870  UMLS:C0020538_hypertensive disease
# 871  UMLS:C0020538_hypertensive disease
#
#                                                Symptom  \
# 859                      UMLS:C0002962_angina pectoris
# 860                             UMLS:C0004093_asthenia
# 861                           UMLS:C0008031_pain chest
# 862                            UMLS:C0012833_dizziness
# 863                                UMLS:C0015967_fever
# 864                               UMLS:C0027497_nausea
# 865                          UMLS:C0030252_palpitation
# 866  UMLS:C0038990_sweat^UMLS:C0700590_sweating inc...
# 867                              UMLS:C0039070_syncope
# 868                              UMLS:C0042571_vertigo
# 869                                 UMLS:C0085639_fall
# 870                  UMLS:C0392680_shortness of breath
# 871                       UMLS:C0438716_pressure chest
#
#      Count of Disease Occurrence
# 859                       5513.0
# 860                       5513.0
# 861                       5513.0
# 862                       5513.0
# 863                       2150.0
# 864                       5513.0
# 865                       3363.0
# 866                       5513.0
# 867                       5513.0
# 868                       5513.0
# 869                       3363.0
# 870                       5513.0
# 871                       5513.0

# %% [markdown]
# <div style = "color: #923333; font-size: 20px">
#     Smoothing data and estimate prior distribution and liklihood of each symptom in dataset
# </div>

# %%
Disease = data_set["Disease"].drop_duplicates()
clean_Symptom = data_set["Symptom"].drop_duplicates()
d = []
s = []
c = []
for i in range(53734):
    c.append(0)

# %%
for i,v in Disease.iteritems():
    for j,value in clean_Symptom.iteritems():
        s1 = v
        d.append(s1)
        s1 = value
        s.append(s1)

# %%
d_s = pd.DataFrame(list(zip(d, s, c)), columns =['Disease', 'Symptom', 'Count of Disease Occurrence'])
data_smooth = pd.concat([data_set, d_s])
data_smooth = data_smooth.drop_duplicates(subset=['Disease', 'Symptom'])
data_smooth["Count of Disease Occurrence"] += 1

# %%
data_smooth
# Out:
#                                                  Disease  \
# 0      UMLS:C0001175_acquiredÂ immuno-deficiency synd...
# 1      UMLS:C0001175_acquiredÂ immuno-deficiency synd...
# 2      UMLS:C0001175_acquiredÂ immuno-deficiency synd...
# 3      UMLS:C0001175_acquiredÂ immuno-deficiency synd...
# 4      UMLS:C0001175_acquiredÂ immuno-deficiency synd...
# ...                                                  ...
# 53729                            UMLS:C1623038_cirrhosis
# 53730                            UMLS:C1623038_cirrhosis
# 53731                            UMLS:C1623038_cirrhosis
# 53732                            UMLS:C1623038_cirrhosis
# 53733                            UMLS:C1623038_cirrhosis
#
#                                                  Symptom  \
# 0                           UMLS:C0008033_pleuritic pain
# 1                                    UMLS:C0010200_cough
# 2                                 UMLS:C0011991_diarrhea
# 3                                    UMLS:C0015967_fever
# 4      UMLS:C0026827_muscle hypotonia^UMLS:C0241938_h...
# ...                                                  ...
# 53729                        UMLS:C0000727_abdomen acute
# 53730                      UMLS:C0425491_catching breath
# 53731                      UMLS:C0740844_air fluid level
# 53732                         UMLS:C0232894_pneumatouria
# 53733                            UMLS:C1167754_fecaluria
#
#        Count of Disease Occurrence
# 0                            351.0
# 1                            351.0
# 2                            351.0
# 3                            351.0
# 4                            351.0
# ...                            ...
# 53729                          1.0
# 53730                          1.0
# 53731                          1.0
# 53732                          1.0
# 53733                          1.0
#
# [53734 rows x 3 columns]

# %%
summ = data_smooth.groupby("Disease").transform('sum')
summ = summ["Count of Disease Occurrence"]
data_smooth["sum"] = summ
data_smooth["probability"] = data_smooth["Count of Disease Occurrence"] / data_smooth["sum"]
data_smooth
# Out:
#                                                  Disease  \
# 0      UMLS:C0001175_acquiredÂ immuno-deficiency synd...
# 1      UMLS:C0001175_acquiredÂ immuno-deficiency synd...
# 2      UMLS:C0001175_acquiredÂ immuno-deficiency synd...
# 3      UMLS:C0001175_acquiredÂ immuno-deficiency synd...
# 4      UMLS:C0001175_acquiredÂ immuno-deficiency synd...
# ...                                                  ...
# 53729                            UMLS:C1623038_cirrhosis
# 53730                            UMLS:C1623038_cirrhosis
# 53731                            UMLS:C1623038_cirrhosis
# 53732                            UMLS:C1623038_cirrhosis
# 53733                            UMLS:C1623038_cirrhosis
#
#                                                  Symptom  \
# 0                           UMLS:C0008033_pleuritic pain
# 1                                    UMLS:C0010200_cough
# 2                                 UMLS:C0011991_diarrhea
# 3                                    UMLS:C0015967_fever
# 4      UMLS:C0026827_muscle hypotonia^UMLS:C0241938_h...
# ...                                                  ...
# 53729                        UMLS:C0000727_abdomen acute
# 53730                      UMLS:C0425491_catching breath
# 53731                      UMLS:C0740844_air fluid level
# 53732                         UMLS:C0232894_pneumatouria
# 53733                            UMLS:C1167754_fecaluria
#
#        Count of Disease Occurrence   sum  probability
# 0                            351.0  5301    0.0662139
# 1                            351.0  5301    0.0662139
# 2                            351.0  5301    0.0662139
# 3                            351.0  5301    0.0662139
# 4                            351.0  5301    0.0662139
# ...                            ...   ...          ...
# 53729                          1.0  3017  0.000331455
# 53730                          1.0  3017  0.000331455
# 53731                          1.0  3017  0.000331455
# 53732                          1.0  3017  0.000331455
# 53733                          1.0  3017  0.000331455
#
# [53734 rows x 5 columns]

# %% [markdown]
# <div style = "color: #923333; font-size: 20px">
#     Build find function to guess the disease from some symptom by doctors
# </div>

# %%
def find():
    ele = [];
    symptom = {"Disease":[], "Symptom":[], "Count of Disease Occurrence":[], "sum":[], "probability":[]};
    symptom = pd.DataFrame(symptom)
    
    n = int(input("Enter number of Symptom : "))
    
    for i in range(0, n): 
        ele.append(str(input("Enter Symptom " + str(i+1))))
    
    for i in range(0, n):
        symptom = pd.concat([symptom, data_smooth[data_smooth["Symptom"] == ele[i]]]).groupby(by = ["Disease"], as_index=False)["probability"].aggregate(pd.np.prod)
        
    symptom = symptom.nlargest(10,'probability');
    return symptom

# %%
Expected_diseases = find()
Expected_diseases
# Out:
# Enter number of Symptom : 5
# Enter Symptom 1UMLS:C0008033_pleuritic pain
# Enter Symptom 2UMLS:C0011991_diarrhea
# Enter Symptom 3UMLS:C0012833_dizziness
# Enter Symptom 4UMLS:C0008031_pain chest
# Enter Symptom 5UMLS:C0438716_pressure chest
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   if sys.path[0] == '':
#                                                Disease   probability
# 51                           UMLS:C0019112_hemorrhoids  4.888003e-13
# 118                   UMLS:C0149931_migraine disorders  1.593089e-13
# 62                  UMLS:C0020538_hypertensive disease  1.512638e-13
# 11                            UMLS:C0004610_bacteremia  1.498571e-13
# 61                        UMLS:C0020473_hyperlipidemia  1.425535e-13
# 69                              UMLS:C0022116_ischemia  1.241565e-13
# 70                        UMLS:C0022658_kidney disease  1.089680e-13
# 109                    UMLS:C0039239_tachycardia sinus  5.239262e-14
# 25   UMLS:C0008350_cholelithiasis^UMLS:C0242216_bil...  4.379432e-14
# 78                              UMLS:C0025202_melanoma  3.782023e-14

# %% [markdown]
# <div style = "color: #923333; font-size: 20px">
#     Build symptom function to guess some symptoms from disease from fin function
# </div>

# %%
Expected_diseases = Expected_diseases.head(3)
def symptoms():
    symptom = {"Disease":[], "Symptom":[], "Count of Disease Occurrence":[], "sum":[], "probability":[]};
    symptom = pd.DataFrame(symptom)
    for i,j in Expected_diseases["Disease"].iteritems():
        x = data_smooth[data_smooth["Disease"] == j]
        x = x.nlargest(3,'Count of Disease Occurrence');
        symptom = pd.concat([symptom, x])
    return symptom

# %%
symptoms()
# Out:
#                                  Disease                        Symptom  \
# 716            UMLS:C0019112_hemorrhoids           UMLS:C0009024_clonus
# 717            UMLS:C0019112_hemorrhoids            UMLS:C0010200_cough
# 718            UMLS:C0019112_hemorrhoids         UMLS:C0011991_diarrhea
# 1629    UMLS:C0149931_migraine disorders    UMLS:C0002416_ambidexterity
# 1630    UMLS:C0149931_migraine disorders        UMLS:C0012833_dizziness
# 1631    UMLS:C0149931_migraine disorders            UMLS:C0015967_fever
# 859   UMLS:C0020538_hypertensive disease  UMLS:C0002962_angina pectoris
# 860   UMLS:C0020538_hypertensive disease         UMLS:C0004093_asthenia
# 861   UMLS:C0020538_hypertensive disease       UMLS:C0008031_pain chest
#
#       Count of Disease Occurrence    sum probability
# 716                          81.0   1681   0.0481856
# 717                          81.0   1681   0.0481856
# 718                          81.0   1681   0.0481856
# 1629                         62.0    828   0.0748792
# 1630                         62.0    828   0.0748792
# 1631                         62.0    828   0.0748792
# 859                        5514.0  64407   0.0856118
# 860                        5514.0  64407   0.0856118
# 861                        5514.0  64407   0.0856118
